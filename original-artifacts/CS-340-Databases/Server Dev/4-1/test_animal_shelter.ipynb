# %%
from animal_shelter import AnimalShelter

# Instantiate the AnimalShelter class
shelter = AnimalShelter()
# Out:
# Connected to MongoDB successfully

# %%
# Test the create method
data = {
    "rec_num": 9999,
    "age_upon_outcome": "2 years",
    "animal_id": "A999999",
    "animal_type": "Dog",
    "breed": "Labrador Mix",
    "color": "Brown",
    "date_of_birth": "2023-01-01",
    "datetime": "2025-05-31 18:00:00",
    "monthyear": "2025-05-31T18:00:00",
    "name": "TestDog",
    "outcome_subtype": "Adoption",
    "outcome_type": "Adoption",
    "sex_upon_outcome": "Neutered Male",
    "location_lat": 30.5,
    "location_long": -97.5,
    "age_upon_outcome_in_weeks": 104
}

# Call the create method
result = shelter.create(data)
print("Create result:", result)
# Out:
# Create result: True

# %%
# Test the read method
query = {"animal_id": "A999999"}
results = shelter.read(query)
print("Read results:")
for doc in results:
    print(doc)
# Out:
# Read results:
# {'_id': ObjectId('683b9f190bd84e4dd107b586'), 'rec_num': 9999, 'age_upon_outcome': '2 years', 'animal_id': 'A999999', 'animal_type': 'Dog', 'breed': 'Labrador Mix', 'color': 'Brown', 'date_of_birth': '2023-01-01', 'datetime': '2025-05-31 18:00:00', 'monthyear': '2025-05-31T18:00:00', 'name': 'TestDog', 'outcome_subtype': 'Adoption', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5, 'location_long': -97.5, 'age_upon_outcome_in_weeks': 104}

# %%
# Test read with another query
query = {"animal_type": "Dog"}
results = shelter.read(query)
print("Read results (Dogs):")
for doc in results[:5]:
    print(doc)
# Out:
# Read results (Dogs):
# {'_id': ObjectId('683b9f190bd84e4dd107b586'), 'rec_num': 9999, 'age_upon_outcome': '2 years', 'animal_id': 'A999999', 'animal_type': 'Dog', 'breed': 'Labrador Mix', 'color': 'Brown', 'date_of_birth': '2023-01-01', 'datetime': '2025-05-31 18:00:00', 'monthyear': '2025-05-31T18:00:00', 'name': 'TestDog', 'outcome_subtype': 'Adoption', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5, 'location_long': -97.5, 'age_upon_outcome_in_weeks': 104}
